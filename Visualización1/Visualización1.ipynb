# %%
import matplotlib.pyplot as plt
import numpy as np # Ya que usaremos algunas de sus funciones ;)
import seaborn as sns
import pandas as pd
df_iris = sns.load_dataset("iris")

# %% [markdown]
# 📌 Para poder solucionar los ejercicios de hoy no solo tendremos que visualizar, también tendremos que usar métodos que hemos aprendido en lecciones anteriores de Pandas como por ejemplo value_counts(), isnull, describe, etc.
# Tendréis que realizar gráficas para contestar a las siguientes preguntas:

# %%
df = pd.read_csv('df_csv_modificado.csv')
df.head(1)
# Out:
#    unnamed:_0    year     type country        area  \
# 0           0  2018.0  Boating     USA  California
#
#                       location  activity         name sex_ age   time  \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
#
#       species_                                               href  \
# 0  White shark  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#   case_number.1 case_number.2
# 0    2018.06.25    2018.06.25

# %%
df['sex_'].value_counts()
# Out:
# M      4939
# F       619
# M         2
# N         2
# lli       1
# .         1
# Name: sex_, dtype: int64

# %%
#EJERCICIO 1: ¿Cuál es la frecuencia de cada una de las categorías de la columna sex?

plt.figure()
x = df['sex_'].value_counts()
y = ['M','F','M','N','lli','.']
plt.bar(y,x)
plt.show()

# %%
#EJERCICIO 2: ¿Cuál es el porcentaje de nulos por columna? Usa un pie chart donde incluyáis el porcentaje de cada variable en el interior del quesito. 
#Para eso tendréis que usar el parámetro autopct, aquí algo de documentación.

# %%
nulos = ((df.isnull().sum() / len(df))*100)
print(nulos)
# Out:
# unnamed:_0        0.000000
# year              0.000000
# type              0.065424
# country           0.654236
# area              6.673209
# location          7.981681
# activity          8.357867
# name              3.271181
# sex_              8.995747
# age              43.604841
# time             52.011776
# species_         44.242722
# href              0.000000
# case_number.1     0.000000
# case_number.2     0.000000
# dtype: float64

# %%
fig,ax=plt.subplots(figsize=[10,10])

x = np.array(df.columns)
y = np.array(nulos)
ax.pie(y, labels=x, autopct="%0.02f %%")
plt.show()

# %%
df.describe()
# Out:
#         unnamed:_0         year
# count  6114.000000  6114.000000
# mean   3065.554629  1968.831207
# std    1769.652139    43.745920
# min       0.000000  1801.000000
# 25%    1534.250000  1946.000000
# 50%    3066.500000  1980.000000
# 75%    4596.750000  2005.000000
# max    6131.000000  2018.000000

# %%
unnamed=df['unnamed:_0'].unique().sum()
unnamed
# Out:
# 18742801

# %%
year=df['year'].unique().sum()
year
# Out:
# 396196.0

# %%
#EJERCICIO 3: ¿Cuál es el número total de valores únicos de cada una de las columnas categóricas del DataFrame?

fig,ax=plt.subplots(figsize=[10,10])

x = unnamed, year
ax.pie(x, labels=['unnamed','year'], autopct='%0.02f%%')
plt.show()

# %%
#EJERCICIO 4: Filtrad los datos para quedarnos solo con los datos de USA.

usa=df[df['country']=='USA']
usa.head(0)
# Out:
# Empty DataFrame
# Columns: [unnamed:_0, year, type, country, area, location, activity, name, sex_, age, time, species_, href, case_number.1, case_number.2]
# Index: []

# %%
usa.to_csv('usa.csv')

# %%
lista=[]
for c in usa:
    lista.append(usa[c].value_counts().sum())

print(lista)
# Out:
# [2200, 2200, 2200, 2200, 2197, 2151, 2069, 2171, 2103, 1496, 1379, 1313, 2200, 2200, 2200]

# %%
fig,ax=plt.subplots(figsize=[10,10])

x = lista
y= usa.columns
ax.pie(x, labels=y, autopct='%0.2f%%')
plt.show()

# %%
#¿Cuántos ataques de tiburones hubo en USA a lo largo del tiempo? Muestra solo los que hayan ocurrido del 2000 en adelante.

usa.head(2)
# Out:
#    unnamed:_0    year        type country        area  \
# 0           0  2018.0     Boating     USA  California
# 1           1  2018.0  Unprovoked     USA     Georgia
#
#                          location  activity             name sex_ age  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  57
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  11
#
#             time     species_  \
# 0          18h00  White shark
# 1  14h00  -15h00          NaN
#
#                                                 href case_number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
#
#   case_number.2
# 0    2018.06.25
# 1    2018.06.18

# %%
usa2000=usa[usa['year']>2000]

ataques=usa2000['year'].value_counts()

# %%
años=usa2000['year'].unique()

# %%
fig,ax=plt.subplots(figsize=[10,10])

x = ataques
y= años
ax.pie(x, labels=y, autopct='%0.2f%%')
plt.show()

# %%
#En función del tipo, ¿cuántos ataques de tiburones de cada tipo hubo en USA? Muestra los resultados en un gráfico de línea.

# %%
tipo=usa['species_'].value_counts()
especie=usa['species_'].unique()

# %%
especie=np.delete(especie, [1], axis=None)

# %%
len(tipo)
# Out:
# 635

# %%
len(especie)
# Out:
# 635

# %%
fig,ax=plt.subplots(figsize=[50,20])

x = tipo
y= especie
ax.plot(y,x)
plt.show()
# Out:
# /Users/veronicabellidosanmartin/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/veronicabellidosanmartin/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/veronicabellidosanmartin/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/veronicabellidosanmartin/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#EJERCICIO 5: Filtrad los datos para Spain:

spain=df[df['country']=='SPAIN']
spain.head(2)
spain.to_csv('spain.csv')

# %%
#¿Cuántos ataques de tiburones hubo en España a lo largo del tiempo? Muestra solo los que hayan ocurrido del 2000 en adelante.

# %%
spain2000=spain[spain['year']>2000]

ataques=spain2000['year'].value_counts()

# %%
años=spain2000['year'].unique()

# %%
fig,ax=plt.subplots(figsize=[10,10])

x = ataques
y= años
ax.pie(x, labels=y, autopct='%0.2f%%')
plt.show()

# %%
#En función del tipo, ¿cuántos ataques de cada tipo de tiburones hubo en España? Muestra los resultados en un gráfico de línea.

# %%
spain.head()
# Out:
#      unnamed:_0    year        type country               area  \
# 82           82  2017.0  Unprovoked   SPAIN     Canary Islands
# 98           98  2017.0     Invalid   SPAIN          Castellón
# 113         113  2017.0  Unprovoked   SPAIN            Majorca
# 130         130  2017.0  Unprovoked   SPAIN       Ibiza Island
# 233         234  2016.0  Unprovoked   SPAIN  Alicante Province
#
#                            location      activity    name sex_  age  \
# 82                    Gran Canaria   Body surfing    male    M   13
# 98                  Grao de Moncofa      Swimming  female    F   11
# 113  Estanys Beach, Colonia de Sant      Swimming  female    F  NaN
# 130                Playa den Bossa      Swimming    male    M   82
# 233                Arenales del Sol      Swimming    male    M   40
#
#           time                        species_  \
# 82         NaN                Porbeagle, 1.5 m
# 98      Midday  Shark involvement questionable
# ...

# %%
tipo=spain['species_'].value_counts()
especie=spain['species_'].unique()

# %%
especie=np.delete(especie, [3], axis=None)

# %%
fig,ax=plt.subplots(figsize=[10,10])

x = tipo
y= especie
ax.pie(x, labels=y, autopct='%0.2f%%')
plt.show()

# %%
fig,ax=plt.subplots(figsize=[50,20])

x = tipo
y= especie
ax.plot(y,x)
plt.show()
