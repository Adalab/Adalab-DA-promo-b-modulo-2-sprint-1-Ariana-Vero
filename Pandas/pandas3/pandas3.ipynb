# %%
#Cargar el dataset
#💡 Pista Si hacemos la carga del dataset sin el parámetro encoding nos puede dar error. Aquí tenéis una lista de los encodings disponibles en pandas. Buscad por los encoding de tipo ISO.

import pandas as pd

# %%
df=pd.read_csv('attacks.csv')
df
# Out:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 0              0    2018.06.25  2018.0       Boating        USA
# 1              1    2018.06.18  2018.0    Unprovoked        USA
# 2              2    2018.06.09  2018.0       Invalid        USA
# 3              3    2018.06.08  2018.0    Unprovoked  AUSTRALIA
# 4              4    2018.06.04  2018.0      Provoked     MEXICO
# ...          ...           ...     ...           ...        ...
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 0            California       Oceanside, San Diego County
# 1               Georgia    St. Simon Island, Glynn County
# ...

# %%
#Haced una exploración básica del DataFrame:
#¿Cuántas filas y columnas tiene el DataFrame?

df.shape
# Out:
# (6114, 22)

# %%
#Mostrad las primeras cinco filas 

df.head()  #No hace falta añadir el número de filas porque por defecto, escoge las 5 primeras
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
#y las últimas cinco filas del DataFrame.

df.tail()
# Out:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 6109    New South Wales    Georges Head, off Port Jackson
# 6110     South Carolina                    Off Charleston
# 6111  Western Australia  Hamelin Harbour, at Faure Island
# 6112                NaN                               NaN
# 6113                NaN                               NaN
#
#                              Activity                             Name Sex   \
# 6109                              NaN                             boat  NaN
# ...

# %%
#Mostrad 2 filas al azar del DataFrame.

df.sample(2)
# Out:
#       Unnamed: 0 Case Number    Year        Type Country        Area  \
# 4              4  2018.06.04  2018.0    Provoked  MEXICO      Colima
# 1090        1095  2009.08.30  2009.0  Unprovoked     USA  California
#
#                              Location     Activity            Name Sex   ...  \
# 4                            La Ticla  Free diving  Gustavo Ramos     M  ...
# 1090  Huntington Beach, Orange County      Surfing  Cory Hedgepeth    M  ...
#
#              Species  Investigator or Source                       pdf  \
# 4     Tiger shark, 3m              A .Kipper      2018.06.04-Ramos.pdf
# 1090         4' shark       R. Collier, GSAF  2009.08.30-Hedgepeth.pdf
#
#                                            href formula  \
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1090  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# ...

# %%
#¿Cuál es el nombre de las columnas del DataFrame?

df.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.

df.describe() #variables numéricas
# Out:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000
# 50%    3066.500000  1980.000000     3236.500000
# 75%    4596.750000  2005.000000     4768.750000
# max    6131.000000  2018.000000     6303.000000

# %%
df.info() #variables categóricas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6114 entries, 0 to 6113
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              6114 non-null   int64
#  1   Case Number             6113 non-null   object
#  2   Year                    6114 non-null   float64
#  3   Type                    6110 non-null   object
#  4   Country                 6074 non-null   object
#  5   Area                    5706 non-null   object
#  6   Location                5626 non-null   object
#  7   Activity                5603 non-null   object
#  8   Name                    5914 non-null   object
#  9   Sex                     5564 non-null   object
#  10  Age                     3448 non-null   object
#  11  Time                    2934 non-null   object
#  12  Species                 3409 non-null   object
#  13  Investigator or Source  6098 non-null   object
# ...

# %%
conteo=df.shape[0]
# Out:
# 6114

# %%
#¿Cuál es el porcentaje de valores nulos en cada columna?

nulos=df.isnull().sum()
porcentaje=nulos/conteo * 100
porcentaje
# Out:
# year                       0.000000
# type                       0.065424
# country                    0.654236
# area                       6.673209
# location                   7.981681
# activity                   8.357867
# name                       3.271181
# sex                        8.995747
# age                       43.604841
# time                      52.011776
# species                   44.242722
# investigator or source     0.261694
# pdf                        0.000000
# href formula               0.016356
# href                       0.000000
# case number.1              0.000000
# case number.2              0.000000
# original order             0.000000
# unnamed: 22               99.983644
# unnamed: 23               99.967288
# dtype: float64

# %%
#Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.
dict_valores = {}  #Definimos un diccionario vacío para poder añadir valores y key.

for col in df:
   unicos=df[col]. unique ()
   unicos_cont=df.value_counts(col)
   for k, v in zip(unicos, unicos_cont): 
      dict_valores[k] = v #Para cada key y value en el bucle for asignamos un valor a cada uno a partir del zip de las dos listas.
print(dict_valores)

# %%
#Cambiad el nombre de las columnas para que todas estén en minúsculas

columns_minusculas = {col :  col.lower() for col in df.columns}
columns_minusculas

# %%
df.rename(columns=columns_minusculas,inplace=True)

# %%
df.head(1)
# Out:
#    unnamed: 0 case number    year     type country        area  \
# 0           0  2018.06.25  2018.0  Boating     USA  California
#
#                       location  activity         name sex   ...     species   \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F  ...  White shark
#
#   investigator or source                   pdf  \
# 0       R. Collier, GSAF  2018.06.25-Wolfe.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
#
#   case number.2 original order unnamed: 22  unnamed: 23
# 0    2018.06.25         6303.0         NaN          NaN
#
# [1 rows x 22 columns]

# %%
# y reemplazad los espacios por _.

espacios_columns={col:col.strip() for col in df.columns}
espacios_columns
# Out:
# {'unnamed: 0': 'unnamed: 0',
#  'case number': 'case number',
#  'year': 'year',
#  'type': 'type',
#  'country': 'country',
#  'area': 'area',
#  'location': 'location',
#  'activity': 'activity',
#  'name': 'name',
#  'sex ': 'sex',
#  'age': 'age',
#  'time': 'time',
#  'species ': 'species',
#  'investigator or source': 'investigator or source',
#  'pdf': 'pdf',
#  'href formula': 'href formula',
#  'href': 'href',
#  'case number.1': 'case number.1',
#  'case number.2': 'case number.2',
#  'original order': 'original order',
#  'unnamed: 22': 'unnamed: 22',
#  'unnamed: 23': 'unnamed: 23'}

# %%
df.replace(to_replace= df.columns,value=espacios_columns,inplace=True)

df.head(1)
# Out:
#    unnamed: 0 case number    year     type country        area  \
# 0           0  2018.06.25  2018.0  Boating     USA  California
#
#                       location  activity         name sex   ...     species   \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F  ...  White shark
#
#   investigator or source                   pdf  \
# 0       R. Collier, GSAF  2018.06.25-Wolfe.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
#
#   case number.2 original order unnamed: 22  unnamed: 23
# 0    2018.06.25         6303.0         NaN          NaN
#
# [1 rows x 22 columns]

# %%
#Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, Investigator or Source, pdf, href formula.

df.drop(['unnamed: 22', 'unnamed: 23', 'case number', 'original order', 'investigator or source', 'pdf', 'href formula'], axis=1)
# Out:
#       unnamed: 0    year          type    country               area  \
# 0              0  2018.0       Boating        USA         California
# 1              1  2018.0    Unprovoked        USA            Georgia
# 2              2  2018.0       Invalid        USA             Hawaii
# 3              3  2018.0    Unprovoked  AUSTRALIA    New South Wales
# 4              4  2018.0      Provoked     MEXICO             Colima
# ...          ...     ...           ...        ...                ...
# 6109        6127  1804.0          Boat  AUSTRALIA    New South Wales
# 6110        6128  1803.0  Sea Disaster        USA     South Carolina
# 6111        6129  1803.0    Unprovoked  AUSTRALIA  Western Australia
# 6112        6130  1802.0    Unprovoked      INDIA                NaN
# 6113        6131  1801.0      Provoked        NaN                NaN
#
#                               location                         activity  \
# ...

# %%
#Establece la columna Case Number como índice del DataFrame.

df.set_index(['unnamed: 0'], inplace=True)
df.head()
# Out:
#               year        type    country             area  \
# unnamed: 0
# 0           2018.0     Boating        USA       California
# 1           2018.0  Unprovoked        USA          Georgia
# 2           2018.0     Invalid        USA           Hawaii
# 3           2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           2018.0    Provoked     MEXICO           Colima
#
#                                   location     activity             name sex   \
# unnamed: 0
# 0              Oceanside, San Diego County     Paddling      Julie Wolfe    F
# 1           St. Simon Island, Glynn County     Standing  Adyson McNeely     F
# 2                             Habush, Oahu      Surfing      John Denges    M
# 3                       Arrawarra Headland      Surfing             male    M
# 4                                 La Ticla  Free diving   Gustavo Ramos     M
#
#             age           time         species   \
# unnamed: 0
# 0            57          18h00      White shark
# ...

# %%
#Guarda el csv que no tiene esas columnas para seguir usándolo mañana.

df.to_csv('df_csv_modificado.csv')
